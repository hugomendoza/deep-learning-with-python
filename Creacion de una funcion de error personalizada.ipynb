# %% [markdown]
# # Funcion de error personalizada con Tensorflow

# %%
import tensorflow as tf

tf.__version__
# Out:
# '2.13.0'

# %% [markdown]
# ## Huber loss

# %% [markdown]
# La función de pérdida de Huber describe la pena incurrida por un procedimiento de estimación f. Huber (1964) define la función de pérdida de forma fragmentada por:
#
# $$ {\displaystyle L_{\delta }(y,h(x))={\begin{cases}{\frac {1}{2}}(y-h(x))^{2} \hspace{1.5cm} {\textrm {for}}|y-h(x)|\leq \delta ,\\\delta \,|y-h(x)|-{\frac {1}{2}}\delta ^{2} \hspace{5mm} {\textrm {otherwise.}}\end{cases}}}$$
#
# Más información: https://en.wikipedia.org/wiki/Huber_loss

# %%
# Función que genera al función de pérdida de Huber
def create_huber(threshold=1.0):
    def huber_fn(y_true, y_pred):
        error = y_true - y_pred
        is_small_error = tf.abs(error) <= threshold
        squared_loss = tf.square(error) / 2
        linear_loss  = threshold * tf.abs(error) - threshold**2 / 2
        return tf.where(is_small_error, squared_loss, linear_loss)
    return huber_fn

# %% [markdown]
# A continuación se representa gráficamente la función de pérdida de Huber en función del threshold seleccionado

# %%
# El valor más habitual para la función de pérdida de Huber es 1.0
huber_fn = create_huber(1.0)

# %%
# Representación gráfica de la función de pérdida de Huber
from matplotlib import pyplot as plt
import numpy as np

plt.figure(figsize=(10, 5.5))

z = np.linspace(-4, 4, 200)

plt.plot(z, huber_fn(0, z), "b-", linewidth=2, label="huber($z$)")

plt.gca().axvline(x=0, color='k')
plt.axis([-4, 4, 0, 4])
plt.grid(True)
plt.xlabel("$z$")
plt.ylabel("$huber\_loss(0, z)$")
plt.legend(fontsize=14)
plt.title("Huber loss", fontsize=14)
plt.show()

# %% [markdown]
# ## Entrenando una Red Neuronal Artificial con la nueva función de error

# %% [markdown]
# A continuación se pone en práctica la función de error definida en el apartado anterior en un ejercicio práctico. Para ello, se va a utilizar el caso de uso práctico de predicción del precio de una vivienda presentado en la sección de introducción a Keras

# %% [markdown]
# ### Importando el conjunto de datos

# %%
from tensorflow.keras import datasets

# %%
boston_housing = datasets.boston_housing

# %%
(X_train, y_train), (X_test, y_test) = boston_housing.load_data()

# %%
import pandas as pd

features = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]

df_train = pd.DataFrame(np.column_stack([X_train, y_train]), columns=features)
df_train.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0  1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1  0.02177  82.5   2.03   0.0  0.415  7.610   15.7  6.2700   2.0  348.0
# 2  4.89822   0.0  18.10   0.0  0.631  4.970  100.0  1.3325  24.0  666.0
# 3  0.03961   0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 4  3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
# 5  0.28392   0.0   7.38   0.0  0.493  5.708   74.3  4.7211   5.0  287.0
# 6  9.18702   0.0  18.10   0.0  0.700  5.536  100.0  1.5804  24.0  666.0
# 7  4.09740   0.0  19.58   0.0  0.871  5.468  100.0  1.4118   5.0  403.0
# 8  2.15505   0.0  19.58   0.0  0.871  5.628  100.0  1.5166   5.0  403.0
# 9  1.62864   0.0  21.89   0.0  0.624  5.019  100.0  1.4394   4.0  437.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     21.0  396.90  18.72  15.2
# 1     14.7  395.38   3.11  42.3
# 2     20.2  375.52   3.26  50.0
# 3     20.2  396.90   8.01  21.1
# 4     20.2  391.43  14.65  17.7
# 5     19.6  391.13  11.74  18.5
# 6     20.2  396.90  23.60  11.3
# 7     14.7  396.90  26.42  15.6
# 8     14.7  169.27  16.65  15.6
# 9     21.2  396.90  34.41  14.4

# %% [markdown]
# ### División del conjunto de datos

# %%
from sklearn.model_selection import train_test_split

X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5)

# %% [markdown]
# ### Escalando el conjunto de datos

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

X_train_prep = scaler.fit_transform(X_train)
X_val_prep = scaler.transform(X_val)
X_test_prep = scaler.transform(X_test)

# %% [markdown]
# ### Definicion de la arquitectura de la Red Neuronal Artificial

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

# %%
network = models.Sequential()

network.add(layers.Dense(30, activation='relu', input_shape=X_train.shape[1:]))
network.add(layers.Dense(10, activation='relu'))
network.add(layers.Dense(1))

# %%
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                420
#
#  dense_1 (Dense)             (None, 10)                310
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 741 (2.89 KB)
# Trainable params: 741 (2.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Entrenamiento de la Red Neuronal Artificial

# %% [markdown]
# #### Función de error utilizada en el ejercicio práctico de introducción a Keras

# %% [markdown]
# A continuación se muestra la representación gráfica de la evaluación de los valores resultantes de la función de error **_mean_squared_error_** durante el proceso de entrenamiento.

# %%
network.compile(
    loss='mean_squared_error',
    optimizer='adam',
    metrics=['mae']
               )

# %%
history = network.fit(X_train_prep, 
                      y_train, 
                      epochs=50, 
                      validation_data=(X_val_prep, y_val))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 1s 16ms/step - loss: 625.1428 - mae: 23.3671 - val_loss: 600.4962 - val_mae: 22.8103
# Epoch 2/50
# 13/13 [==============================] - 0s 3ms/step - loss: 597.8937 - mae: 22.7435 - val_loss: 579.6517 - val_mae: 22.2855
# Epoch 3/50
# 13/13 [==============================] - 0s 4ms/step - loss: 580.1830 - mae: 22.2920 - val_loss: 565.3264 - val_mae: 21.8917
# Epoch 4/50
# 13/13 [==============================] - 0s 3ms/step - loss: 567.1090 - mae: 21.9225 - val_loss: 554.0974 - val_mae: 21.5642
# Epoch 5/50
# 13/13 [==============================] - 0s 4ms/step - loss: 555.4988 - mae: 21.5914 - val_loss: 542.3638 - val_mae: 21.2423
# Epoch 6/50
# 13/13 [==============================] - 0s 4ms/step - loss: 542.7429 - mae: 21.2089 - val_loss: 527.8166 - val_mae: 20.8074
# Epoch 7/50
# 13/13 [==============================] - 0s 3ms/step - loss: 526.0228 - mae: 20.6799 - val_loss: 508.0663 - val_mae: 20.2358
# Epoch 8/50
# 13/13 [==============================] - 0s 3ms/step - loss: 504.4520 - mae: 20.0550 - val_loss: 482.2568 - val_mae: 19.6253
# Epoch 9/50
# 13/13 [==============================] - 0s 3ms/step - loss: 478.6449 - mae: 19.4410 - val_loss: 454.2792 - val_mae: 18.9767
# Epoch 10/50
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# #### Evaluación de los resultados

# %%
test_loss, test_mae = network.evaluate(X_test_prep, y_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 44.0439 - mae: 5.0496

# %%
print('test_mae:', test_mae)
# Out:
# test_mae: 5.049576759338379

# %% [markdown]
# #### Función de error de Huber

# %% [markdown]
# A continuación se muestra la representación gráfica de la evaluación de los valores resultantes de la función de error de **_huber_** durante el proceso de entrenamiento.

# %%
network = models.Sequential()

network.add(layers.Dense(30, activation='relu', input_shape=X_train.shape[1:]))
network.add(layers.Dense(10, activation='relu'))
network.add(layers.Dense(1))

# %%
network.compile(
    loss=create_huber(1.0),
    optimizer='adam',
    metrics=['mae']
               )

# %%
history = network.fit(X_train_prep, 
                      y_train, 
                      epochs=50, 
                      validation_data=(X_val_prep, y_val))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 1s 12ms/step - loss: 22.4756 - mae: 22.9756 - val_loss: 22.0833 - val_mae: 22.5833
# Epoch 2/50
# 13/13 [==============================] - 0s 4ms/step - loss: 22.0425 - mae: 22.5425 - val_loss: 21.6870 - val_mae: 22.1870
# Epoch 3/50
# 13/13 [==============================] - 0s 4ms/step - loss: 21.6829 - mae: 22.1829 - val_loss: 21.3295 - val_mae: 21.8295
# Epoch 4/50
# 13/13 [==============================] - 0s 3ms/step - loss: 21.2997 - mae: 21.7997 - val_loss: 20.9388 - val_mae: 21.4388
# Epoch 5/50
# 13/13 [==============================] - 0s 4ms/step - loss: 20.7980 - mae: 21.2975 - val_loss: 20.3015 - val_mae: 20.8015
# Epoch 6/50
# 13/13 [==============================] - 0s 4ms/step - loss: 20.1129 - mae: 20.6113 - val_loss: 19.5865 - val_mae: 20.0865
# Epoch 7/50
# 13/13 [==============================] - 0s 3ms/step - loss: 19.4182 - mae: 19.9138 - val_loss: 18.8393 - val_mae: 19.3364
# Epoch 8/50
# 13/13 [==============================] - 0s 4ms/step - loss: 18.7241 - mae: 19.2218 - val_loss: 18.1575 - val_mae: 18.6541
# Epoch 9/50
# 13/13 [==============================] - 0s 3ms/step - loss: 18.0791 - mae: 18.5756 - val_loss: 17.4280 - val_mae: 17.9204
# Epoch 10/50
# 13/13 [==============================] - 0s 4ms/step - loss: 17.3506 - mae: 17.8461 - val_loss: 16.6618 - val_mae: 17.1618
# Epoch 11/50
# 13/13 [==============================] - 0s 4ms/step - loss: 16.5581 - mae: 17.0542 - val_loss: 15.7522 - val_mae: 16.2468
# Epoch 12/50
# 13/13 [==============================] - 0s 3ms/step - loss: 15.5665 - mae: 16.0614 - val_loss: 14.7315 - val_mae: 15.2299
# Epoch 13/50
# 13/13 [==============================] - 0s 4ms/step - loss: 14.4825 - mae: 14.9778 - val_loss: 13.7931 - val_mae: 14.2798
# Epoch 14/50
# 13/13 [==============================] - 0s 4ms/step - loss: 13.4477 - mae: 13.9444 - val_loss: 12.8950 - val_mae: 13.3904
# Epoch 15/50
# 13/13 [==============================] - 0s 3ms/step - loss: 12.4891 - mae: 12.9827 - val_loss: 12.1643 - val_mae: 12.6643
# Epoch 16/50
# 13/13 [==============================] - 0s 3ms/step - loss: 11.7983 - mae: 12.2938 - val_loss: 11.4696 - val_mae: 11.9683
# Epoch 17/50
# 13/13 [==============================] - 0s 3ms/step - loss: 2.9284 - mae: 3.3882 - val_loss: 2.8194 - val_mae: 3.2964
# Epoch 39/50
# 13/13 [==============================] - 0s 3ms/step - loss: 2.7389 - mae: 3.1909 - val_loss: 2.6643 - val_mae: 3.1549
# Epoch 40/50
# 13/13 [==============================] - 0s 3ms/step - loss: 2.5869 - mae: 3.0408 - val_loss: 2.5099 - val_mae: 2.9938
# Epoch 41/50
# 13/13 [==============================] - 0s 3ms/step - loss: 2.4954 - mae: 2.9503 - val_loss: 2.3832 - val_mae: 2.8633
# Epoch 42/50
# 13/13 [==============================] - 0s 3ms/step - loss: 2.4126 - mae: 2.8635 - val_loss: 2.2663 - val_mae: 2.7389
# Epoch 43/50
# 13/13 [==============================] - 0s 3ms/step - loss: 2.3371 - mae: 2.7858 - val_loss: 2.1969 - val_mae: 2.6689
# Epoch 44/50
# 13/13 [==============================] - 0s 3ms/step - loss: 2.2737 - mae: 2.7157 - val_loss: 2.1426 - val_mae: 2.5796
# Epoch 45/50
# 13/13 [==============================] - 0s 3ms/step - loss: 2.2383 - mae: 2.6830 - val_loss: 2.0428 - val_mae: 2.4864
# Epoch 46/50
# 13/13 [==============================] - 0s 3ms/step - loss: 2.1853 - mae: 2.6290 - val_loss: 1.9955 - val_mae: 2.4267
# Epoch 47/50
# 13/13 [==============================] - 0s 3ms/step - loss: 2.1467 - mae: 2.5884 - val_loss: 1.9326 - val_mae: 2.3584
# Epoch 48/50
# 13/13 [==============================] - 0s 3ms/step - loss: 2.1138 - mae: 2.5575 - val_loss: 1.9091 - val_mae: 2.3402
# Epoch 49/50
# 13/13 [==============================] - 0s 3ms/step - loss: 2.0967 - mae: 2.5381 - val_loss: 1.8752 - val_mae: 2.2962
# Epoch 50/50
# 13/13 [==============================] - 0s 3ms/step - loss: 2.0633 - mae: 2.5038 - val_loss: 1.8166 - val_mae: 2.2556

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history)[['mae', 'val_mae']].plot(figsize=(10, 6))
plt.grid(True)
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# #### Evaluación de los resultados

# %%
test_loss, test_mae = network.evaluate(X_test_prep, y_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 3.4853 - mae: 3.9592

# %%
print('test_mae:', test_mae)
# Out:
# test_mae: 3.9592065811157227

# %% [markdown]
# ## Guardando el modelo en disco con objetos personalizados

# %% [markdown]
# Cuando nuestro modelo contiene algún componente personalizado, debemos realizar el siguiente procedimiento para almacenar el modelo en disco e importarlo cuando sea necesario

# %%
# Guardamos el modelo en disco
network.save("modelo_huber_loss.h5")
# Out:
# C:\Users\Hugo\anaconda3\envs\curso_deep_learning\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Importamos el modelo previamente guardado en disco
network2 = tf.keras.models.load_model("modelo_huber_loss.h5",
                                      custom_objects={"huber_fn": create_huber(1.0)})

# %%
history = network2.fit(X_train_prep, 
                      y_train, 
                      epochs=2, 
                      validation_data=(X_val_prep, y_val))
# Out:
# Epoch 1/2
# 13/13 [==============================] - 0s 12ms/step - loss: 2.0375 - mae: 2.4778 - val_loss: 1.8125 - val_mae: 2.2341
# Epoch 2/2
# 13/13 [==============================] - 0s 3ms/step - loss: 2.0161 - mae: 2.4594 - val_loss: 1.7735 - val_mae: 2.2025
